# %%
from source3 import your_function
from user_input2 import ticker, start_date, end_date, short_window, long_window
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from source3 import your_function
#       2 from user_input2 import ticker, start_date, end_date, short_window, long_window
#
# ModuleNotFoundError: No module named 'source3'

# %%
import nbformat
from nbconvert import PythonExporter

# Read the .ipynb file and extract code cells
with open("user_input2.ipynb", "r", encoding="utf-8") as f:
    notebook = nbformat.read(f, as_version=4)

code_cells = []
for cell in notebook.cells:
    if cell.cell_type == "code":
        code_cells.append(cell.source)

# Execute the code cells
for code in code_cells:
    exec(code)

data = yf.download(ticker, start=start_date, end=end_date)

# Continue with the rest of your code
# ...
# Out:
# Text(value='', description='Ticker:')
# DatePicker(value=None, description='Start Date:', step=1)
# DatePicker(value=None, description='End Date:', step=1)
# RadioButtons(description='Strategy:', options=(('Short-term trader (<6 months)', 1), ('Medium-term trader (6-1…
# Dropdown(description='Crossover:', options=(), value=None)
# Button(description='Submit', style=ButtonStyle())
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 15
#      13 # Execute the code cells
#      14 for code in code_cells:
# ---> 15     exec(code)
#      17 data = yf.download(ticker, start=start_date, end=end_date)
#
# File <string>:4
#
# KeyError: None

# %%
# %run source3.ipynb
# %run user_input2.ipynb
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  price   short_SMA    long_SMA  signal  positions
# Date
# 2021-04-14  328.279999         NaN         NaN     0.0        NaN
# 2021-04-15  322.750000         NaN         NaN     0.0        0.0
# 2021-04-16  342.000000         NaN         NaN     0.0        0.0
# 2021-04-19  333.000000         NaN         NaN     0.0        0.0
# 2021-04-20  320.820007         NaN         NaN     0.0        0.0
# ...                ...         ...         ...     ...        ...
# 2021-11-08  353.920013  309.681501  257.643900     1.0        0.0
# 2021-11-09  357.390015  315.084502  258.924901     1.0        0.0
# 2021-11-10  328.600006  319.175502  259.984901     1.0        0.0
# 2021-11-11  336.390015  322.995003  261.124101     1.0        0.0
# 2021-11-12  342.980011  326.113504  262.293801     1.0        0.0
#
# [150 rows x 5 columns]
#                  price   short_SMA    long_SMA  signal  positions
# Date
# ...
